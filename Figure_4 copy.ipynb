# %%
import sys
sys.path.append("figures_material")
from bnet_viz import render_bnet_graph

art = render_bnet_graph(
    bnet_path="figures_material/networks/SO.bnet",  # or bnet_text=...
    max_per_row=9,
    order_mode="osci_order",       # "hierarchical_order" | "random_order" | "osci_order"
    osci_top_pct=0.5,
    osci_seed=42,
    x_gap=2.2, y_gap=2.8,          # grid spacing
    y_merge_threshold=1,           # NEW: merge Y with outputs if outputs count <= this
    node_shape="circle",           # "circle" or "ellipse" or anything Graphviz supports
    node_width=1.2, node_height=1.2,
    fontsize=14,
    output_dir="figures_material/figure_4",
    base_name="SO_graph_final",
    fontname="Dejavu Sans",
    bold_labels=True,
    focus_targets=["MCPS"],
)
art
# Out:
# {'dot': 'figures_material\\figure_4\\SO_graph_final.dot',
#  'png': 'figures_material\\figure_4\\SO_graph_final.png',
#  'svg': 'figures_material\\figure_4\\SO_graph_final.svg',
#  'positions_json': 'figures_material\\figure_4\\SO_graph_final_positions.json',
#  'neato_found': True,
#  'order_mode': 'osci_order',
#  'max_per_row_internal': 9,
#  'max_per_row_input': None,
#  'max_per_row_output': None,
#  'focus_targets': ['MCPS'],
#  'focus_max_hops': None,
#  'num_nodes_drawn': 10,
#  'num_edges_drawn': 25}

# %%
import sys
sys.path.append("figures_material")
from bnet_viz import render_bnet_graph

art = render_bnet_graph(
    bnet_path="figures_material/networks/SO.bnet",  # or bnet_text=...
    max_per_row=7,
    order_mode="osci_order",       # "hierarchical_order" | "random_order" | "osci_order"
    osci_top_pct=0.4,
    osci_seed=86,
    x_gap=2.1, y_gap=2.5,          # grid spacing
    y_merge_threshold=1,           # NEW: merge Y with outputs if outputs count <= this
    node_shape="circle",           # "circle" or "ellipse" or anything Graphviz supports
    node_width=1.2, node_height=1.2,
    fontsize=14,
    output_dir="figures_material/figure_4",
    base_name="SO_graph_final",
    fontname="Dejavu Sans",
    bold_labels=True,
    focus_targets=["SO_2"],
)
art
# Out:
# {'dot': 'figures_material\\figure_4\\SO_graph_final.dot',
#  'png': 'figures_material\\figure_4\\SO_graph_final.png',
#  'svg': 'figures_material\\figure_4\\SO_graph_final.svg',
#  'positions_json': 'figures_material\\figure_4\\SO_graph_final_positions.json',
#  'neato_found': True,
#  'order_mode': 'osci_order',
#  'max_per_row_internal': 7,
#  'max_per_row_input': None,
#  'max_per_row_output': None,
#  'focus_targets': ['SO_2'],
#  'focus_max_hops': None,
#  'num_nodes_drawn': 45,
#  'num_edges_drawn': 160}
